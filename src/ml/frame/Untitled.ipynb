# %%
import pandas as pd

# %%
df = pd.read_csv('input/results_complete_linear.csv')

# %%
df
# Out:
#        natural_frequency_1  natural_frequency_2  natural_frequency_3  \
# 0                 0.273377            30.783811           302.858478
# 1                 0.144774            17.278703           209.017713
# 2                 0.121243             8.961036           107.526737
# 3                 0.276419            13.198426            57.834367
# 4                 0.571167            30.843616           110.777751
# ...                    ...                  ...                  ...
# 44995             0.000941             0.003957             0.000607
# 44996             0.003527             0.016576             0.005111
# 44997             0.007825             0.038239             0.014665
# 44998             0.013831             0.068818             0.029216
# 44999             0.021540             0.108188             0.048645
#
#        natural_frequency_4  natural_frequency_5  natural_frequency_6  \
# ...
